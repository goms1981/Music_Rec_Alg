# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
from sklearn.model_selection import train_test_split

# %%
file_path="/Users/sa15/Desktop/Music lab /Music_Rec_Alg/train.csv"
Music=pd.read_csv(file_path)

# %%
Music=Music.dropna()
Music
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28357       82447               mack 10                10 million ways
# 28358       82448                m.o.p.  ante up (robbin hoodz theory)
# 28359       82449                  nine                  whutcha want?
# 28360       82450            will smith                         switch
# 28361       82451                 jeezy                         r.i.p.
#
#        release_date    genre  \
# 0              1950      pop
# 1              1950      pop
# ...

# %%
Music.isnull().sum()
# Out:
# Unnamed: 0                  0
# artist_name                 0
# track_name                  0
# release_date                0
# genre                       0
# lyrics                      0
# len                         0
# dating                      0
# violence                    0
# world/life                  0
# night/time                  0
# shake the audience          0
# family/gospel               0
# romantic                    0
# communication               0
# obscene                     0
# music                       0
# movement/places             0
# light/visual perceptions    0
# family/spiritual            0
# sadness                     0
# feelings                    0
# topic                       0
# age                         0
# dtype: int64

# %% [markdown]
# ### Dropping Null Values: Above shows no null values to drop.

# %%
Music_new= Music.drop(columns=['lyrics'])
Music_new
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28357       82447               mack 10                10 million ways
# 28358       82448                m.o.p.  ante up (robbin hoodz theory)
# 28359       82449                  nine                  whutcha want?
# 28360       82450            will smith                         switch
# 28361       82451                 jeezy                         r.i.p.
#
#        release_date    genre  len    dating  violence  world/life  night/time  \
# ...

# %%
Music_new.drop_duplicates(inplace=True)

# %%
Music_new.to_csv('Music_new.csv',index=False)
Music_new
# Out:
#        Unnamed: 0           artist_name                     track_name  \
# 0               0                mukesh           mohabbat bhi jhoothi
# 1               4         frankie laine                      i believe
# 2               6           johnnie ray                            cry
# 3              10           pérez prado                       patricia
# 4              12  giorgos papadopoulos             apopse eida oneiro
# ...           ...                   ...                            ...
# 28357       82447               mack 10                10 million ways
# 28358       82448                m.o.p.  ante up (robbin hoodz theory)
# 28359       82449                  nine                  whutcha want?
# 28360       82450            will smith                         switch
# 28361       82451                 jeezy                         r.i.p.
#
#        release_date    genre  len    dating  violence  world/life  night/time  \
# ...
